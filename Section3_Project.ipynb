# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import re

# %%
beer_list = ['kloud', 'fitz super clear', 'Asahi super dry', 'Tsingtao', 'Heineken',
 'Kirin ichiban', 'Sapporo Premium Beer / Draft Beer', 'stella artois', 'guinness braught',
 '1664 Blanc', 'pilsner urquell', 'San Miguel', 'OB premier pilsner', 'cass fresh',
 'stout', 'dry finish', 'max hite', 'hite extra cold', 'victoria bitter', 'BINTANG pilsner',
 'krombacher weizen', 'Miller Genuine Draft', 'Hoegaarden Cherry', 'TIGER REDLER',
 "Suntory The Premium Malt's", 'REEPER B Weissbier', 'PEEPER B IPA', 'TIGER BEER',
 'TSINGTAO WHEAT BEER', 'Erdinger Weissbier', 'Carlsberg', 'Budweiser ', 'Hoegarden',
 'YEBISU', 'Paulaner Hefe-weissbier', 'Desperados', 'Peroni Nastro Azzurro',
 'Edelweiss Snowfresh', 'Heineken Dark Lager', 'Kozel Dark 10', 'Guinness original',
 'Filite', 'SEOULITE ALE', 'JEJU WIT ALE', 'Stephans Brau Philsner', 'Stephans Brau Larger',
 'Stephans Bräu Hefe-Weizen Naturtrüb', 'Bali Hai Premium Larger', 'Apostel Brau',
 'Egger Zwickl', 'Egger Marzenbier', 'Holsten Premium Beer', 'Franzisaner Hefe-Weissbier',
 'Egger Radler Grapefruit', 'Barvaria Premium', 'Barvaria 8.6', 'Lapin Kulta IV A',
 'Grolsch Premium Larger', 'Gambrinus Original', 'XXXX Gold', 'Leffe Brown',
 'Lowenbrau Original', 'Asahi Super dray Black ', 'Harbin Beer', "beck's",
 'Hoegaarden Rosee', 'Platinum White Ale', 'Platinum Pale Ale', 'Ambar Especial Larger',
 'Schöfferhofer Grapefruit', 'Volfas Engelman Grünberger Hefeweizen', 'Berliner Kindl Pilsener ',
 'BURGE MEESTER', 'Red Rock', 'Erdinger Dunkel', 'Warsteiner Premium Verum', "Queen's Ale Blonde Type"]

beer_list = pd.DataFrame(data=beer_list, columns=['검색이름'])

data = pd.DataFrame(data=[], columns=['맥주정보', '검색이름', '맥주이름'])

chromedriver = 'chromedriver.exe'

# %%
chromedriver = 'chromedriver.exe'
url = 'https://www.ratebeer.com/search?tab=beer'
driver = webdriver.Chrome(chromedriver)
driver.get(url)
driver.set_window_size(900, 900)
time.sleep(3)
element = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div/input')
time.sleep(3)
element.click()
time.sleep(3)
element.send_keys('kloud')
time.sleep(3)
driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div[2]/a[1]/div/div[2]').click()
time.sleep(3)
beer_name = driver.find_element(By.CSS_SELECTOR, '.MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.mt-3.MuiTypography-h4').text
print(beer_name)
string = driver.find_element(By.CLASS_NAME, 'MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.MuiTypography-h6').text
print(string)
extract = re.compile('[0-9]*,*[0-9]+')
str_num = extract.findall(string)
str_num = str_num[0]
print(str_num)

if ',' in str_num:
    str_num = str_num.split(',')
    str_num = int(str_num[0]+str_num[1])
    num = str_num
else:
    num = int(str_num)

print(num)

time.sleep(3)
element = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
time.sleep(3)
driver.execute_script("arguments[0].click();", element)

page_num = num // 15 + 1

for i in range(page_num):
    print(i+1, '번째 페이지입니다.')

    time.sleep(3)
    beer_info = driver.find_elements(By.CSS_SELECTOR, '.px-4.fj-s.f-wrap')
    print(beer_info[0].text)
    tmp = []
    for i in range(15):
        tmp.append(beer_info[i].text)

    tmp = pd.DataFrame(data=tmp, columns=['맥주정보'])
    tmp['맥주이름'] = beer_name
    tmp['검색이름'] = 'kloud'
    data = pd.concat([data, tmp])

    print(data)
# Out:
# C:\Users\oopp9\AppData\Local\Temp\ipykernel_55680\3586441523.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# Kloud Original Gravity
# Reviews (108)
# 108
# 108
# 1 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [135 rows x 3 columns]
# 2 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [150 rows x 3 columns]
# 3 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [165 rows x 3 columns]
# 4 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [180 rows x 3 columns]
# 5 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [195 rows x 3 columns]
# 6 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [210 rows x 3 columns]
# 7 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [225 rows x 3 columns]
# 8 번째 페이지입니다.
# italianjohn(5,276)
# 🇺🇸Penndel, United States
# 2.8September 6, 2021
# Clear golden blonde pour with a thin white head and spots of lacing …. Aroma of sweet malts, caramel malt, some light floral notes, grape  and a little bit of lemon … taste is of the…
# Show more
# BOTTLE
# Aroma
# 5
# Appearance
# 3
# Flavor
# 5
# Mouthfeel
# 3
# Overall
# 12
#                                                  맥주정보   검색이름  \
# 0   italianjohn(5,276)\n🇺🇸Penndel, United States\n...  kloud
# 1   orda(284)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2   Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3   geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4   Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..                                                ...    ...
# 10  deanso(15,284)\n🇬🇧Doncaster, England\n2.3Janua...  kloud
# 11  onceblind(17,734)\n🇺🇸Denver, United States\n3....  kloud
# 12  DrNosha(7,429)\n🇩🇪Württemberg, Germany\n2.3Dec...  kloud
# 13  mkel07(10,012)\n🇦🇺Brisbane, Australia\n2.4Octo...  kloud
# 14  bladerunner53(23)\n🇳🇱Netherlands\n2.5October 9...  kloud
#
#                       맥주이름
# 0   Kloud Original Gravity
# 1   Kloud Original Gravity
# 2   Kloud Original Gravity
# 3   Kloud Original Gravity
# 4   Kloud Original Gravity
# ..                     ...
# 10  Kloud Original Gravity
# 11  Kloud Original Gravity
# 12  Kloud Original Gravity
# 13  Kloud Original Gravity
# 14  Kloud Original Gravity
#
# [240 rows x 3 columns]

# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import re

beer_list = ['Leffe Brown',
 'Lowenbrau Original', 'Asahi Super dray Black ', 'Harbin Beer', "beck's",
 'Hoegaarden Rosee', 'Platinum White Ale', 'Platinum Pale Ale', 'Ambar Especial Larger',
 'Schöfferhofer Grapefruit', 'Volfas Engelman Grünberger Hefeweizen', 'Berliner Kindl Pilsener ',
 'BURGE MEESTER', 'Red Rock', 'Erdinger Dunkel', 'Warsteiner Premium Verum', "Queen's Ale Blonde Type"]

beer_list = pd.DataFrame(data=beer_list, columns=['검색이름'])

data = pd.DataFrame(data=[], columns=['맥주정보', '검색이름', '맥주이름'])

chromedriver = 'chromedriver.exe'

url = 'https://www.ratebeer.com/search?tab=beer'

# driver = webdriver.Chrome(chromedriver)
# driver.get(url)
# driver.set_window_size(900, 900)
# time.sleep(3)

# element = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div/input')
# time.sleep(3)
# element.click()

def crawl(driver, beer, data, k):
    print('url_open {0} 맥주 데이터를 수집합니다.'.format(beer))
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    driver.set_window_size(900, 900)
    time.sleep(3)
    element = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div/input')
    time.sleep(3)
    element.click()
    time.sleep(3)
    element.send_keys(beer)
    time.sleep(3)

    driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div[2]/a[1]/div/div[2]').click()
    time.sleep(3)
    beer_name = driver.find_element(By.CSS_SELECTOR, '.MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.mt-3.MuiTypography-h4').text

    error_cnt = 0

    while True:
        try:
            time.sleep(3)
            string = driver.find_element(By.CLASS_NAME, 'MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.MuiTypography-h6').text

            extract = re.compile('[0-9]*,*[0-9]+')
            str_num = extract.findall(string)
            str_num = str_num[0]

            print('성공 while문을 탈출합니다.')
            break
        except:
            print('오류 다시 시작합니다.')

            error_cnt += 1

            if error_cnt == 5:
                print('연속된 오류로 다음 맥주로 넘어갑니다.')
                return
    
    if ',' in str_num:
        str_num = str_num.split(',')
        str_num = int(str_num[0]+str_num[1])
        num = str_num
    else:
        num = int(str_num)

    time.sleep(3)
    element = driver.find_element(By.XPATH, '//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
    time.sleep(3)
    driver.execute_script("arguments[0].click();", element)
    
    page_num = num // 15 + 1

    for i in range(page_num):
        print(i+1, '번째 페이지입니다.')

        time.sleep(3)
        beer_info = driver.find_elements(By.CSS_SELECTOR, '.px-4.fj-s.f-wrap')

        tmp = []

        for i in range(len(beer_info)):
            tmp.append(beer_info[i].text)

        tmp = pd.DataFrame(data=tmp, columns=['맥주정보'])
        tmp['맥주이름'] = beer_name
        tmp['검색이름'] = beer
        data = pd.concat([data, tmp])

        try:
            element = driver.find_element(By.XPATH, '//button[@title="Next page"]/span[@class="MuiIconButton-label"]')
            time.sleep(3)
            driver.execute_script("arguments[0].click();", element)
        except:
            print("마지막 페이지입니다.")

    if num != len(data):
        data = data[:num]

    print('리뷰수 : ', num, '수집된 리뷰수 :', len(data))

    result = pd.merge(data, beer_list, on='검색이름', how='left')
    result.to_csv("beer_n"+str(k + 59)+".csv", encoding='utf-8')

    driver.quit()

    return result
    
for k in range(len(beer_list)):
    result = crawl(driver, beer_list['검색이름'].iloc[k], data, k)
# Out:
# url_open Leffe Brown 맥주 데이터를 수집합니다.
# C:\Users\oopp9\AppData\Local\Temp\ipykernel_55680\1387863853.py:34: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# 성공 while문을 탈출합니다.
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# 55 번째 페이지입니다.
# 56 번째 페이지입니다.
# 57 번째 페이지입니다.
# 58 번째 페이지입니다.
# 59 번째 페이지입니다.
# 60 번째 페이지입니다.
# 61 번째 페이지입니다.
# 62 번째 페이지입니다.
# 63 번째 페이지입니다.
# 64 번째 페이지입니다.
# 65 번째 페이지입니다.
# 66 번째 페이지입니다.
# 67 번째 페이지입니다.
# 68 번째 페이지입니다.
# 69 번째 페이지입니다.
# 70 번째 페이지입니다.
# 71 번째 페이지입니다.
# 72 번째 페이지입니다.
# 73 번째 페이지입니다.
# 74 번째 페이지입니다.
# 75 번째 페이지입니다.
# 76 번째 페이지입니다.
# 77 번째 페이지입니다.
# 78 번째 페이지입니다.
# 79 번째 페이지입니다.
# 80 번째 페이지입니다.
# 81 번째 페이지입니다.
# 82 번째 페이지입니다.
# 83 번째 페이지입니다.
# 84 번째 페이지입니다.
# 85 번째 페이지입니다.
# 86 번째 페이지입니다.
# 87 번째 페이지입니다.
# 88 번째 페이지입니다.
# 89 번째 페이지입니다.
# 90 번째 페이지입니다.
# 91 번째 페이지입니다.
# 92 번째 페이지입니다.
# 93 번째 페이지입니다.
# 94 번째 페이지입니다.
# 95 번째 페이지입니다.
# 96 번째 페이지입니다.
# 97 번째 페이지입니다.
# 98 번째 페이지입니다.
# 99 번째 페이지입니다.
# 100 번째 페이지입니다.
# 101 번째 페이지입니다.
# 102 번째 페이지입니다.
# 103 번째 페이지입니다.
# 104 번째 페이지입니다.
# 105 번째 페이지입니다.
# 106 번째 페이지입니다.
# 107 번째 페이지입니다.
# 108 번째 페이지입니다.
# 109 번째 페이지입니다.
# 110 번째 페이지입니다.
# 111 번째 페이지입니다.
# 112 번째 페이지입니다.
# 113 번째 페이지입니다.
# 114 번째 페이지입니다.
# 115 번째 페이지입니다.
# 116 번째 페이지입니다.
# 117 번째 페이지입니다.
# 118 번째 페이지입니다.
# 119 번째 페이지입니다.
# 120 번째 페이지입니다.
# 121 번째 페이지입니다.
# 122 번째 페이지입니다.
# 123 번째 페이지입니다.
# 124 번째 페이지입니다.
# 125 번째 페이지입니다.
# 126 번째 페이지입니다.
# 127 번째 페이지입니다.
# 128 번째 페이지입니다.
# 129 번째 페이지입니다.
# 130 번째 페이지입니다.
# 131 번째 페이지입니다.
# 132 번째 페이지입니다.
# 133 번째 페이지입니다.
# 134 번째 페이지입니다.
# 135 번째 페이지입니다.
# 136 번째 페이지입니다.
# 137 번째 페이지입니다.
# 138 번째 페이지입니다.
# 139 번째 페이지입니다.
# 140 번째 페이지입니다.
# 141 번째 페이지입니다.
# 142 번째 페이지입니다.
# 143 번째 페이지입니다.
# 144 번째 페이지입니다.
# 145 번째 페이지입니다.
# 146 번째 페이지입니다.
# 147 번째 페이지입니다.
# 148 번째 페이지입니다.
# 149 번째 페이지입니다.
# 150 번째 페이지입니다.
# 151 번째 페이지입니다.
# 152 번째 페이지입니다.
# 153 번째 페이지입니다.
# 154 번째 페이지입니다.
# 155 번째 페이지입니다.
# 156 번째 페이지입니다.
# 157 번째 페이지입니다.

# %%
read_data = pd.read_csv("beer_n0.csv")

read_data
# Out:
#      Unnamed: 0                                               맥주정보   검색이름  \
# 0             0  italianjohn(5,273)\n🇺🇸Penndel, United States\n...  kloud
# 1             1  orda(283)\n🇺🇸Aurora, United States\n3.9August ...  kloud
# 2             2  Radek Kliber(8,065)\n🇨🇦Toronto (Can) Krotoszyn...  kloud
# 3             3  geologyguy(2,575)\n🇺🇸Columbia, United States\n...  kloud
# 4             4  Wolff90(203)\n🇸🇪Upplands Väsby, Sweden\n1.0Feb...  kloud
# ..          ...                                                ...    ...
# 103         103  fredthecat(548)\n🇨🇦Canada\n1.8November 4, 2014...  kloud
# 104         104  dhunter151(590)\n🇺🇸Santa Rosa, United States\n...  kloud
# 105         105  maus(46)\n🇪🇪Tartu, Estonia\n2.3July 17, 2014\n...  kloud
# 106         106  hojoo(4)\n2.8July 16, 2014\nunfortunately, too...  kloud
# 107         107  migojarad(3)\n🇰🇷Seoul, South Korea\n2.1June 17...  kloud
#
#                        맥주이름
# 0    Kloud Original Gravity
# 1    Kloud Original Gravity
# 2    Kloud Original Gravity
# 3    Kloud Original Gravity
# 4    Kloud Original Gravity
# ..                      ...
# 103  Kloud Original Gravity
# 104  Kloud Original Gravity
# 105  Kloud Original Gravity
# 106  Kloud Original Gravity
# 107  Kloud Original Gravity
#
# [108 rows x 4 columns]

# %%
guinness = pd.read_csv("beer_n40.csv")
guinness
# Out:
#      Unnamed: 0                                               맥주정보  \
# 0             0  borderline_alco(187)\n🇬🇧Durham, England\n3.3Se...
# 1             1  Salian(1,761)\n🇬🇧Sale, England\n3.5September 4...
# 2             2  reidyboy(1,008)\n🇬🇧Shrewsbury, England\n3.3Jul...
# 3             3  lmlikesstout(614)\n🇬🇧Andover, Hampshire, UK, E...
# 4             4  a-beier(781)\n🇩🇰Denmark\n3.7November 7, 2021\n...
# ..          ...                                                ...
# 611         611  Bloemart(256)\n🇳🇱Netherlands\n1.7August 6, 200...
# 612         612  jerohen(2,619)\n🇳🇱Bussum, Netherlands\n3.2Octo...
# 613         613  caesar(7,642)\n🇳🇱Bunnik, Netherlands\n1.3Augus...
# 614         614  Loic99(23)\n🇱🇺Luxembourg\n1.4July 26, 2001\npe...
# 615         615  DJH-Bird99(207)\n🇳🇱Nijkerk, Netherlands\n2.1No...
#
#                   검색이름                                 맥주이름
# 0    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 1    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 2    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 3    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 4    Guinness original  Guinness Original 4.2% (Ireland/UK)
# ..                 ...                                  ...
# 611  Guinness original  Guinness Original 4.2% (Ireland/UK)
# 612  Guinness original  Guinness Original 4.2% (Ireland/UK)
# 613  Guinness original  Guinness Original 4.2% (Ireland/UK)
# 614  Guinness original  Guinness Original 4.2% (Ireland/UK)
# 615  Guinness original  Guinness Original 4.2% (Ireland/UK)
#
# [616 rows x 4 columns]

# %%
cass = pd.read_csv("beer_n13.csv")
cass
# Out:
#      Unnamed: 0                                               맥주정보  \
# 0             0  m7hildeb(894)\n1.9November 5, 2022\nBottle. Cl...
# 1             1  kingmidas(47)\n1.2September 21, 2022\nTaki kon...
# 2             2  medkung(156)\n🇹🇭Bangkok, Thailand\n2.3Septembe...
# 3             3  midovark(5,283)\n🇳🇱Alkmaar, Netherlands\n1.6Ju...
# 4             4  caribou43(2,685)\n🇨🇭Lausanne, Switzerland\n3.2...
# ..          ...                                                ...
# 303         303  IslandHaole(1,302)\n🇯🇵Misawa, Japan\n0.8May 26...
# 304         304  MrRomero(1,976)\n🇺🇸Nolanville, United States\n...
# 305         305  Ernest(9,184)\n🇺🇸Boulder, United States\n1.5Ma...
# 306         306  Oakes(28,105)\n🇨🇦Richmond, Canada\n1.1March 30...
# 307         307  Brian(145)\n🇨🇦Canada\n2.0March 10, 2002\nThe b...
#
#            검색이름        맥주이름
# 0    cass fresh  Cass Fresh
# 1    cass fresh  Cass Fresh
# 2    cass fresh  Cass Fresh
# 3    cass fresh  Cass Fresh
# 4    cass fresh  Cass Fresh
# ..          ...         ...
# 303  cass fresh  Cass Fresh
# 304  cass fresh  Cass Fresh
# 305  cass fresh  Cass Fresh
# 306  cass fresh  Cass Fresh
# 307  cass fresh  Cass Fresh
#
# [308 rows x 4 columns]

# %%
import pandas as pd

data = pd.DataFrame(data=[], columns = ['맥주정보', '검색이름', '맥주이름'])

# %%
data = pd.concat([guinness, cass])
data
# Out:
#      Unnamed: 0                                               맥주정보  \
# 0             0  borderline_alco(187)\n🇬🇧Durham, England\n3.3Se...
# 1             1  Salian(1,761)\n🇬🇧Sale, England\n3.5September 4...
# 2             2  reidyboy(1,008)\n🇬🇧Shrewsbury, England\n3.3Jul...
# 3             3  lmlikesstout(614)\n🇬🇧Andover, Hampshire, UK, E...
# 4             4  a-beier(781)\n🇩🇰Denmark\n3.7November 7, 2021\n...
# ..          ...                                                ...
# 303         303  IslandHaole(1,302)\n🇯🇵Misawa, Japan\n0.8May 26...
# 304         304  MrRomero(1,976)\n🇺🇸Nolanville, United States\n...
# 305         305  Ernest(9,184)\n🇺🇸Boulder, United States\n1.5Ma...
# 306         306  Oakes(28,105)\n🇨🇦Richmond, Canada\n1.1March 30...
# 307         307  Brian(145)\n🇨🇦Canada\n2.0March 10, 2002\nThe b...
#
#                   검색이름                                 맥주이름
# 0    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 1    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 2    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 3    Guinness original  Guinness Original 4.2% (Ireland/UK)
# 4    Guinness original  Guinness Original 4.2% (Ireland/UK)
# ..                 ...                                  ...
# 303         cass fresh                           Cass Fresh
# 304         cass fresh                           Cass Fresh
# 305         cass fresh                           Cass Fresh
# 306         cass fresh                           Cass Fresh
# 307         cass fresh                           Cass Fresh
#
# [924 rows x 4 columns]

# %%
data = data[['맥주이름', '맥주정보']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 924 entries, 0 to 307
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   맥주이름    924 non-null    object
#  1   맥주정보    924 non-null    object
# dtypes: object(2)
# memory usage: 21.7+ KB

# %%
data['맥주정보'].iloc[0]
# Out:
# 'borderline_alco(187)\n🇬🇧Durham, England\n3.3September 5, 2022\nRoasted malt and toffee, some burnt bread, black coffee, slight sourness. Slight metallic hop finish, with more burnt bread. Thin mouthfeel, but slightly creamy. The cans have…\nShow more\nAroma\n-\nAppearance\n-\nFlavor\n-\nMouthfeel\n-\nOverall\n-'

# %%
df = data.copy()

df['맥주정보'] = df['맥주정보'].str.split('\n')
df['맥주정보']
# Out:
# 0      [borderline_alco(187), 🇬🇧Durham, England, 3.3S...
# 1      [Salian(1,761), 🇬🇧Sale, England, 3.5September ...
# 2      [reidyboy(1,008), 🇬🇧Shrewsbury, England, 3.3Ju...
# 3      [lmlikesstout(614), 🇬🇧Andover, Hampshire, UK, ...
# 4      [a-beier(781), 🇩🇰Denmark, 3.7November 7, 2021,...
#                              ...
# 303    [IslandHaole(1,302), 🇯🇵Misawa, Japan, 0.8May 2...
# 304    [MrRomero(1,976), 🇺🇸Nolanville, United States,...
# 305    [Ernest(9,184), 🇺🇸Boulder, United States, 1.5M...
# 306    [Oakes(28,105), 🇨🇦Richmond, Canada, 1.1March 3...
# 307    [Brian(145), 🇨🇦Canada, 2.0March 10, 2002, The ...
# Name: 맥주정보, Length: 924, dtype: object

# %%
df['맥주정보'].iloc[3]
# Out:
# ['lmlikesstout(614)',
#  '🇬🇧Andover, Hampshire, UK, England',
#  '3.5February 28, 2022',
#  'Bottle 500ml (BB: 25/11/22);',
#  'Look: almost jet black with a light tan head. Moderate carbonation. Nice lacing.…',
#  'Show more',
#  'BOTTLE',
#  '@ Tesco Supermarket (Various locations)',
#  'Aroma',
#  '7',
#  'Appearance',
#  '4',
#  'Flavor',
#  '7',
#  'Mouthfeel',
#  '4',
#  'Overall',
#  '13']

# %%
df['맥주정보'].iloc[1][-10:]
# Out:
# ['Aroma',
#  '7',
#  'Appearance',
#  '4',
#  'Flavor',
#  '7',
#  'Mouthfeel',
#  '3',
#  'Overall',
#  '14']

# %%
df['Aroma'] = df['맥주정보'].apply(lambda x: x[-9])
df['Appearance'] = df['맥주정보'].apply(lambda x: x[-7])
df['Flavor'] = df['맥주정보'].apply(lambda x: x[-5])
df['Mouthfeel'] = df['맥주정보'].apply(lambda x: x[-3])
df['Overall'] = df['맥주정보'].apply(lambda x: x[-1])

# %%
df.head()
# Out:
#                                   맥주이름  \
# 0  Guinness Original 4.2% (Ireland/UK)
# 1  Guinness Original 4.2% (Ireland/UK)
# 2  Guinness Original 4.2% (Ireland/UK)
# 3  Guinness Original 4.2% (Ireland/UK)
# 4  Guinness Original 4.2% (Ireland/UK)
#
#                                                 맥주정보 Aroma Appearance Flavor  \
# 0  [borderline_alco(187), 🇬🇧Durham, England, 3.3S...     -          -      -
# 1  [Salian(1,761), 🇬🇧Sale, England, 3.5September ...     7          4      7
# 2  [reidyboy(1,008), 🇬🇧Shrewsbury, England, 3.3Ju...     6          4      6
# 3  [lmlikesstout(614), 🇬🇧Andover, Hampshire, UK, ...     7          4      7
# 4  [a-beier(781), 🇩🇰Denmark, 3.7November 7, 2021,...     7          4      7
#
#   Mouthfeel Overall
# 0         -       -
# 1         3      14
# 2         4      13
# 3         4      13
# 4         4      15

# %%
df = df[['맥주이름', 'Aroma', 'Appearance', 'Flavor', 'Mouthfeel', 'Overall']]
df
# Out:
#                                     맥주이름 Aroma Appearance Flavor Mouthfeel  \
# 0    Guinness Original 4.2% (Ireland/UK)     -          -      -         -
# 1    Guinness Original 4.2% (Ireland/UK)     7          4      7         3
# 2    Guinness Original 4.2% (Ireland/UK)     6          4      6         4
# 3    Guinness Original 4.2% (Ireland/UK)     7          4      7         4
# 4    Guinness Original 4.2% (Ireland/UK)     7          4      7         4
# ..                                   ...   ...        ...    ...       ...
# 303                           Cass Fresh     2          1      1         2
# 304                           Cass Fresh     2          2      2         2
# 305                           Cass Fresh     2          3      3         2
# 306                           Cass Fresh     2          1      2         2
# 307                           Cass Fresh     4          2      4         2
#
#     Overall
# 0         -
# 1        14
# 2        13
# 3        13
# 4        15
# ..      ...
# 303       2
# 304       5
# 305       5
# 306       4
# 307       8
#
# [924 rows x 6 columns]

# %%
df.iloc[51]
# Out:
# 맥주이름          Guinness Original 4.2% (Ireland/UK)
# Aroma                                           7
# Appearance                                      4
# Flavor                                          6
# Mouthfeel                                       3
# Overall                                        12
# Name: 51, dtype: object

# %%
df.reset_index(drop=True)
# Out:
#                                     맥주이름 Aroma Appearance Flavor Mouthfeel  \
# 0    Guinness Original 4.2% (Ireland/UK)     -          -      -         -
# 1    Guinness Original 4.2% (Ireland/UK)     7          4      7         3
# 2    Guinness Original 4.2% (Ireland/UK)     6          4      6         4
# 3    Guinness Original 4.2% (Ireland/UK)     7          4      7         4
# 4    Guinness Original 4.2% (Ireland/UK)     7          4      7         4
# ..                                   ...   ...        ...    ...       ...
# 919                           Cass Fresh     2          1      1         2
# 920                           Cass Fresh     2          2      2         2
# 921                           Cass Fresh     2          3      3         2
# 922                           Cass Fresh     2          1      2         2
# 923                           Cass Fresh     4          2      4         2
#
#     Overall
# 0         -
# 1        14
# 2        13
# 3        13
# 4        15
# ..      ...
# 919       2
# 920       5
# 921       5
# 922       4
# 923       8
#
# [924 rows x 6 columns]

# %%
df = df[df['Aroma']!='-']
df = df[df['Appearance']!='-']
df = df[df['Flavor']!='-']
df = df[df['Mouthfeel']!='-']
df = df[df['Overall']!='-']
df[df['Aroma']=='-']
# Out:
# Empty DataFrame
# Columns: [맥주이름, Aroma, Appearance, Flavor, Mouthfeel, Overall]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 904 entries, 1 to 307
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   맥주이름        904 non-null    object
#  1   Aroma       904 non-null    object
#  2   Appearance  904 non-null    object
#  3   Flavor      904 non-null    object
#  4   Mouthfeel   904 non-null    object
#  5   Overall     904 non-null    object
# dtypes: object(6)
# memory usage: 49.4+ KB

# %%
df.Aroma.unique()
# Out:
# array(['7', '6', '5', '8', '9', '4', '10', 'Appearance', '3', '2', '1'],
#       dtype=object)

# %%
df[df["Aroma"] == 'Appearance']
# Out:
#                                    맥주이름       Aroma Appearance     Flavor  \
# 66  Guinness Original 4.2% (Ireland/UK)  Appearance     Flavor  Mouthfeel
# 17                           Cass Fresh  Appearance     Flavor  Mouthfeel
# 24                           Cass Fresh  Appearance     Flavor  Mouthfeel
# 33                           Cass Fresh  Appearance     Flavor  Mouthfeel
#
#    Mouthfeel Overall
# 66   Overall       1
# 17   Overall       1
# 24   Overall       1
# 33   Overall       1

# %%
df = df.reset_index(drop=True)

# %%
df[df["Aroma"] == 'Appearance']
# Out:
#                                     맥주이름       Aroma Appearance     Flavor  \
# 55   Guinness Original 4.2% (Ireland/UK)  Appearance     Flavor  Mouthfeel
# 617                           Cass Fresh  Appearance     Flavor  Mouthfeel
# 624                           Cass Fresh  Appearance     Flavor  Mouthfeel
# 631                           Cass Fresh  Appearance     Flavor  Mouthfeel
#
#     Mouthfeel Overall
# 55    Overall       1
# 617   Overall       1
# 624   Overall       1
# 631   Overall       1

# %%
df.drop([55], inplace=True)
df.drop([617], inplace=True)
df.drop([624], inplace=True)
df.drop([631], inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df[df["Aroma"] == 'Appearance']
# Out:
# Empty DataFrame
# Columns: [맥주이름, Aroma, Appearance, Flavor, Mouthfeel, Overall]
# Index: []

# %%
df['Aroma'] = df['Aroma'].astype('int')
df['Appearance'] = df['Appearance'].astype('int')
df['Flavor'] = df['Flavor'].astype('int')
df['Mouthfeel'] = df['Mouthfeel'].astype('int')
df['Overall'] = df['Overall'].astype('int')

# %%
# df.drop_duplicates(keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   맥주이름        900 non-null    object
#  1   Aroma       900 non-null    int32
#  2   Appearance  900 non-null    int32
#  3   Flavor      900 non-null    int32
#  4   Mouthfeel   900 non-null    int32
#  5   Overall     900 non-null    int32
# dtypes: int32(5), object(1)
# memory usage: 24.7+ KB

# %%
df['맥주이름'].value_counts()
# Out:
# Guinness Original 4.2% (Ireland/UK)    602
# Cass Fresh                             298
# Name: 맥주이름, dtype: int64

# %%
df.rename(columns={'맥주이름':'name'}, inplace=True)
df
# Out:
#                                     name  Aroma  Appearance  Flavor  \
# 0    Guinness Original 4.2% (Ireland/UK)      7           4       7
# 1    Guinness Original 4.2% (Ireland/UK)      6           4       6
# 2    Guinness Original 4.2% (Ireland/UK)      7           4       7
# 3    Guinness Original 4.2% (Ireland/UK)      7           4       7
# 4    Guinness Original 4.2% (Ireland/UK)      5           4       5
# ..                                   ...    ...         ...     ...
# 895                           Cass Fresh      2           1       1
# 896                           Cass Fresh      2           2       2
# 897                           Cass Fresh      2           3       3
# 898                           Cass Fresh      2           1       2
# 899                           Cass Fresh      4           2       4
#
#      Mouthfeel  Overall
# 0            3       14
# 1            4       13
# 2            4       13
# 3            4       15
# 4            2       12
# ..         ...      ...
# 895          2        2
# 896          2        5
# 897          2        5
# 898          2        4
# 899          2        8
#
# [900 rows x 6 columns]

# %%
df.describe()
# Out:
#             Aroma  Appearance      Flavor   Mouthfeel     Overall
# count  900.000000  900.000000  900.000000  900.000000  900.000000
# mean     5.173333    3.296667    5.335556    2.814444   10.721111
# std      1.892248    1.057728    1.954619    0.957386    4.096853
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    4.000000    2.000000    8.000000
# 50%      5.000000    3.000000    6.000000    3.000000   12.000000
# 75%      7.000000    4.000000    7.000000    3.000000   14.000000
# max     10.000000    5.000000   10.000000    5.000000   20.000000

# %%
df.to_csv('after_df.csv', encoding='utf-8')

# %%
df = pd.read_csv("after_df.csv", index_col=0)
df
# Out:
#                                     name  Aroma  Appearance  Flavor  \
# 0    Guinness Original 4.2% (Ireland/UK)      7           4       7
# 1    Guinness Original 4.2% (Ireland/UK)      6           4       6
# 2    Guinness Original 4.2% (Ireland/UK)      7           4       7
# 3    Guinness Original 4.2% (Ireland/UK)      7           4       7
# 4    Guinness Original 4.2% (Ireland/UK)      5           4       5
# ..                                   ...    ...         ...     ...
# 895                           Cass Fresh      2           1       1
# 896                           Cass Fresh      2           2       2
# 897                           Cass Fresh      2           3       3
# 898                           Cass Fresh      2           1       2
# 899                           Cass Fresh      4           2       4
#
#      Mouthfeel  Overall
# 0            3       14
# 1            4       13
# 2            4       13
# 3            4       15
# 4            2       12
# ..         ...      ...
# 895          2        2
# 896          2        5
# 897          2        5
# 898          2        4
# 899          2        8
#
# [900 rows x 6 columns]

# %%
from psycopg2.extensions import register_adapter, AsIs
import numpy
import psycopg2

conn = psycopg2.connect(
    host = "peanut.db.elephantsql.com",
    database="marsovhi",
    user="marsovhi",
    password="6evFgIFweSp5EtSeWMSzOklLij6FLLzH"
)

cur = conn.cursor()

cur.execute("DROP TABLE IF EXISTS beer_data")

cur.execute("""set client_encoding = 'UTF8';""")

cur.execute(
    """CREATE TABLE beer_data (
        id INTEGER,
        name VARCHAR(128),
        Aroma INTEGER,
        Appearance INTEGER,
        Flavor INTEGER,
        Mouthfeel INTEGER,
        Overall INTEGER,
        PRIMARY KEY (id)
        );
"""
)

conn.commit()
conn.close()

# %%
from psycopg2.extensions import register_adapter, AsIs
import numpy
import psycopg2

conn = psycopg2.connect(
    host = "peanut.db.elephantsql.com",
    database="marsovhi",
    user="marsovhi",
    password="6evFgIFweSp5EtSeWMSzOklLij6FLLzH"
)

cur = conn.cursor()

def addapt_numpy_float64(numpy_float64):
    return AsIs(numpy_float64)


def addapt_numpy_int64(numpy_int64):
    return AsIs(numpy_int64)


register_adapter(numpy.float64, addapt_numpy_float64)
register_adapter(numpy.int64, addapt_numpy_int64)

df_list = []

for i in range(len(df)):
    df_list.append(
        [
            i,
            df["name"].loc[i],
            df["Aroma"].loc[i],
            df["Appearance"].loc[i],
            df["Flavor"].loc[i],
            df['Mouthfeel'].loc[i],
            df['Overall'].loc[i]
        ]
    )


for j in df_list:
    cur.execute(
        """INSERT INTO beer_data (id, name, Aroma, Appearance, Flavor, Mouthfeel, Overall) VALUES (%s, %s, %s, %s, %s, %s, %s);""",
        (j[0], j[1], j[2], j[3], j[4], j[5], j[6]),
    )

conn.commit()
conn.close()

# %%
conn = psycopg2.connect(
    host = "peanut.db.elephantsql.com",
    database="marsovhi",
    user="marsovhi",
    password="6evFgIFweSp5EtSeWMSzOklLij6FLLzH"
)

cur = conn.cursor()

cur.execute("SELECT * FROM beer_data;")

cur.fetchall()

cur.execute("SELECT * FROM beer_data;")

cur_list = cur.fetchall()

col = 'id', 'name', 'Aroma', 'Appearance', 'Flavor', 'Mouthfeel', 'Overall'
df = pd.DataFrame(columns=col)

for i in range(len(cur_list)):
    df.loc[i] = cur_list[i]

df
# Out:
#       id                                 name  Aroma  Appearance  Flavor  \
# 0      0  Guinness Original 4.2% (Ireland/UK)      7           4       7
# 1      1  Guinness Original 4.2% (Ireland/UK)      6           4       6
# 2      2  Guinness Original 4.2% (Ireland/UK)      7           4       7
# 3      3  Guinness Original 4.2% (Ireland/UK)      7           4       7
# 4      4  Guinness Original 4.2% (Ireland/UK)      5           4       5
# ..   ...                                  ...    ...         ...     ...
# 895  895                           Cass Fresh      2           1       1
# 896  896                           Cass Fresh      2           2       2
# 897  897                           Cass Fresh      2           3       3
# 898  898                           Cass Fresh      2           1       2
# 899  899                           Cass Fresh      4           2       4
#
#      Mouthfeel  Overall
# 0            3       14
# 1            4       13
# 2            4       13
# 3            4       15
# 4            2       12
# ..         ...      ...
# 895          2        2
# 896          2        5
# 897          2        5
# 898          2        4
# 899          2        8
#
# [900 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

df['name'] = df['name'].replace({'Guinness Original 4.2% (Ireland/UK)':0, 'Cass Fresh':1})
df
# Out:
#      name  Aroma  Appearance  Flavor  Mouthfeel  Overall
# 0       0      7           4       7          3       14
# 1       0      6           4       6          4       13
# 2       0      7           4       7          4       13
# 3       0      7           4       7          4       15
# 4       0      5           4       5          2       12
# ..    ...    ...         ...     ...        ...      ...
# 895     1      2           1       1          2        2
# 896     1      2           2       2          2        5
# 897     1      2           3       3          2        5
# 898     1      2           1       2          2        4
# 899     1      4           2       4          2        8
#
# [900 rows x 6 columns]

# %%
y = df['name']
X = df.drop('name', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y,  random_state=42, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=42, stratify=y_train)

print("X_train shape: ", X_train.shape)
print("X_val shape: ", X_val.shape)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape:  (506, 5)
# X_val shape:  (169, 5)
# X_test shape:  (225, 5)

# %%
# mode(): Return the highest frequency value in a Series.
base_major = y_train.mode()[0]

# 타겟 샘플 수 만큼 0이 담긴 리스트를 만듭니다. 기준모델로 예측
y_pred_base = [base_major] * len(y_train)

# %%
from sklearn.metrics import accuracy_score

print("training accuracy: ", accuracy_score(y_train, y_pred_base).round(2))
# Out:
# training accuracy:  0.67

# %%
y_pred_base_val = [base_major] * len(y_val)
print("validation accuracy: ", accuracy_score(y_val, y_pred_base_val).round(2))
# Out:
# validation accuracy:  0.67

# %%
from category_encoders import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=1, criterion="entropy")

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1)

# %%
print("훈련 정확도", model.score(X_train, y_train))
print("검증 정확도", model.score(X_val, y_val))
# Out:
# 훈련 정확도 0.9802371541501976
# 검증 정확도 0.893491124260355

# %%
y_pred = model.predict(X_test)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89       151
#            1       0.79      0.72      0.75        74
#
#     accuracy                           0.84       225
#    macro avg       0.83      0.81      0.82       225
# weighted avg       0.84      0.84      0.84       225

# %%
import pickle

with open("model.pkl", "wb") as pickle_file:
    pickle.dump(model, pickle_file)

# %%
model = pickle.load('model.pkl', 'rb')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\oopp9\codestates\Section3\pro3v2\sample.ipynb Cell 53 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/oopp9/codestates/Section3/pro3v2/sample.ipynb#Z1002sZmlsZQ%3D%3D?line=0'>1</a> model = pickle.load('model.pkl', 'rb')
#
# TypeError: load() takes exactly 1 positional argument (2 given)

# %%
import numpy as np

model = pickle.load(open('model.pkl', 'rb'))

data1 = 3
data2 = 5
data3 = 1
data4 = 3
data5 = 5



arr = np.array([[data1, data2, data3, data4, data5]])
pred = model.predict(arr)
pred
# Out:
# c:\Users\oopp9\anaconda3\envs\beer\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
